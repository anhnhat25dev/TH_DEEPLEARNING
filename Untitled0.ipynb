# %% [markdown]
# <a href="https://colab.research.google.com/github/anhnhat25dev/TH_DEEPLEARNING/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tạo array 1 chiều

# %%
import numpy as np

# cách 1
# tạo list
my_list = [1, 9, 15, 39]
print("Python list:", my_list)

# chuyển list --> Numpy array
my_numpy_array = np.array(my_list)
print("Numpy array:", my_numpy_array)

# cách 2
a = np.array([1, 9, 15, 39])
print(a)
# Out:
# Python list: [1, 9, 15, 39]
# Numpy array: [ 1  9 15 39]
# [ 1  9 15 39]

# %% [markdown]
# tạo array 2 chiều

# %%
import numpy as np

c = np.array([
    (1, 2, 3),
    (4, 5, 6)
])

print(c)
print(c.shape)
print(c.dtype)
